# %% [markdown]
# # Willkommen zu Ihrem ersten Notebook

# %% [markdown]
# ## Ziel
#
# Sie werden den Umgang mit einem Notebook üben. Versetzen Sie sich in die Rolle von Studierenden. Lesen Sie die Texte durch, probieren Sie die Code-Elements aus und lösen Sie die Aufgaben. Spielen Sie ruhig etwas mit dem Notebook!

# %% [markdown]
# # Teil 1: Notebooks kennenlernen

# %% [markdown]
# ## 1. Python programmieren: Ausgabe mit Python

# %% [markdown]
# Um mit Python Text auszugeben, können Sie die Funktion `print()` verwenden. Der Text, der ausgegeben wird, muss in `""`oder `''`eingeschlossen sein.

# %% [markdown]
# **Beispiel 1:**
# mit doppelten Anführungszeichen

# %%
print("Guten Tag und Herzlich Willkommen in Ihrem ersten Jupyter Notebook")

# %% [markdown]
# **Beispiel 2:**
# mit einfachen Anführungszeichen

# %%
print('Guten Tag und Herzlich Willkommen in Ihrem ersten Jupyter Notebook')

# %% [markdown]
# **Hinweis:**
#
# Am Beginn und Ende des Textes muss das gleiche Anführungszeichen stehen, sonst gibt es einen Fehler.

# %% [markdown]
# **Beispiel 3:**
# Testen Sie den folgenden Code. Wie lautet die Fehlermeldung?

# %%
print('Guten Tag und Herzlich Willkommen in Ihrem ersten Jupyter Notebook")

# %% [markdown]
# **Aufgabe 1:**
#
# Geben Sie Ihren Namen aus.

# %%
# Ihre Lösung

# %% [markdown]
# **Aufgabe 2:**
#
# Testen Sie die folgenden Code-Segmente und beobachten Sie die Ausgabe:

# %%
# Segment 1
print("Guten","Tag")

# %%
# Segment 2
print("Guten"'Tag')

# %%
# Segment 3
print("Guten")
print("Tag")

# %% [markdown]
# **Aufgabe 3:**
#
# Führen Sie die folgende Zelle aus und beantworten Sie die Frage.

# %%
# %run data/MC_Fragen.ipynb

# %% [markdown]
# ## 2. Eine interaktive Aufgabe: "lineare Regression"

# %% [markdown]
# In diesem Beispiel gehen wir von verschiedenen Datenpunkten ("Messwerten") aus. Wir nehmen einen linearen Zusammenhang zwischen den beiden Größen, hier $x$ und $y$ an, und wollen diesen durch eine Gerade ($f(x)=a \cdot x + b$) modellieren. Als Fehlermaß dient die Summe der absoluten Differenzen $|y_i - f(x_i)|$.

# %% [markdown]
# Führen Sie den folgenden Code aus. Bewegen Sie die Slider, um die Werte von $a$ und $b$ zu verändern und versuchen Sie, eine möglichst gute Regressionsgerade $f$ (mit minimaler Summe der absoluten Fehler) zu finden.

# %%
# %run data/InteraktiveAufgabe.ipynb

# %% [markdown]
# ## 3. Optionaler Teil: Plots
#
# Wenn Sie schon Programmiererfahrung und noch Zeit haben, können Sie noch dieses [Beispiel zu Plots](Plots.ipynb) ansehen.

# %% [markdown]
# # Teil 2: Reflexion

# %% [markdown]
# Überlegen Sie kurz den Einsatz und die Möglichkeiten von Notebooks und schreiben Sie Stichpunkte auf die ausgeteilten Karten.
#
# 1. Sie waren in der **Rolle eines/einer Studierenden**. Wie bewerten Sie diese erste Erfahrung?  (weiß)
#
# 2. Versetzen Sie sich in Ihre **Rolle als Lehrende:r**.
#     - Wo und wie könnte man Notebooks einsetzen? (grün)
#     - Worauf müsste man achten? (rot)

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/"><img alt="Creative Commons Lizenzvertrag" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-nd/4.0/88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">Dieses Notebook wurde von Christina B. Class für die Lehre an der EAH Jena erstellt. Es ist lizenziert unter einer <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/">Creative Commons Namensnennung - Nicht kommerziell - Keine Bearbeitungen 4.0 International Lizenz</a>.
